# %% [markdown]
# <a href="https://colab.research.google.com/github/JeebakZ/Football_Computer-Vision/blob/main/PL_2_TRACK_WITHOUT_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading Dependencies

# %%
# !pip install inference
# Out:
# Collecting inference
#   Downloading inference-0.42.1-py3-none-any.whl.metadata (24 kB)
# Collecting aiortc~=1.9.0 (from inference)
#   Downloading aiortc-1.9.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting APScheduler<4.0.0,>=3.10.1 (from inference)
#   Downloading APScheduler-3.11.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting asyncua~=1.1.5 (from inference)
#   Downloading asyncua-1.1.5-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: cachetools<6.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (5.5.2)
# Requirement already satisfied: cython~=3.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (3.0.12)
# Collecting python-dotenv~=1.0.0 (from inference)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting fastapi<0.111,>=0.100 (from inference)
#   Downloading fastapi-0.110.3-py3-none-any.whl.metadata (24 kB)
# Collecting numpy<=1.26.4 (from inference)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 780.7 kB/s eta 0:00:00
# Collecting opencv-python<=4.10.0.84,>=4.8.1.78 (from inference)
#   Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting opencv-contrib-python<=4.10.0.84,>=4.8.1.78 (from inference)
#   Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pillow<11.0 (from inference)
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting prometheus-fastapi-instrumentator<=6.0.0 (from inference)
#   Downloading prometheus_fastapi_instrumentator-6.0.0-py3-none-any.whl.metadata (13 kB)
# Collecting redis~=5.0.0 (from inference)
#   Downloading redis-5.0.8-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in /usr/local/lib/python3.11/dist-packages (from inference) (2.32.3)
# Requirement already satisfied: rich<13.10.0,>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (13.9.4)
# Collecting supervision<=0.30.0,>=0.25.1 (from inference)
#   Downloading supervision-0.25.1-py3-none-any.whl.metadata (14 kB)
# Collecting pybase64~=1.0.0 (from inference)
#   Downloading pybase64-1.0.2.tar.gz (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 3.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting scikit-image<=0.24.0,>=0.19.0 (from inference)
#   Downloading scikit_image-0.24.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: requests-toolbelt~=1.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (1.0.0)
# Collecting wheel<=0.45.0,>=0.38.1 (from inference)
#   Downloading wheel-0.45.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (75.1.0)
# Requirement already satisfied: networkx~=3.1 in /usr/local/lib/python3.11/dist-packages (from inference) (3.4.2)
# Requirement already satisfied: pydantic~=2.6 in /usr/local/lib/python3.11/dist-packages (from inference) (2.10.6)
# Collecting pydantic-settings~=2.2 (from inference)
#   Downloading pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: openai<2.0.0,>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from inference) (1.66.3)
# Collecting structlog<25.0.0,>=24.1.0 (from inference)
#   Downloading structlog-24.4.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting zxing-cpp~=2.2.0 (from inference)
#   Downloading zxing_cpp-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Collecting boto3<=1.35.60 (from inference)
#   Downloading boto3-1.35.60-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing_extensions<=4.12.2,>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from inference) (4.12.2)
# Collecting pydot~=2.0.0 (from inference)
#   Downloading pydot-2.0.0-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: shapely<2.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (2.0.7)
# Collecting tldextract~=5.1.2 (from inference)
#   Downloading tldextract-5.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging~=24.0 in /usr/local/lib/python3.11/dist-packages (from inference) (24.2)
# Collecting anthropic~=0.34.2 (from inference)
#   Downloading anthropic-0.34.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pandas<2.3.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (2.2.2)
# Collecting paho-mqtt~=1.6.1 (from inference)
#   Downloading paho-mqtt-1.6.1.tar.gz (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytest<9.0.0,>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (8.3.5)
# Requirement already satisfied: tokenizers<0.22.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from inference) (0.21.1)
# Collecting slack-sdk~=3.33.4 (from inference)
#   Downloading slack_sdk-3.33.5-py2.py3-none-any.whl.metadata (15 kB)
# Collecting twilio~=9.3.7 (from inference)
#   Downloading twilio-9.3.8-py2.py3-none-any.whl.metadata (12 kB)
# Collecting httpx<0.28.0,>=0.25.1 (from inference)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting pylogix==1.0.5 (from inference)
#   Downloading pylogix-1.0.5-py2.py3-none-any.whl.metadata (5.6 kB)
# Collecting pymodbus<=3.8.3,>=3.6.9 (from inference)
#   Downloading pymodbus-3.8.3-py3-none-any.whl.metadata (15 kB)
# Collecting backoff~=2.2.0 (from inference)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting filelock<=3.17.0,>=3.12.0 (from inference)
#   Downloading filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting onnxruntime<1.20.0,>=1.15.1 (from inference)
#   Downloading onnxruntime-1.19.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: nvidia-ml-py<13.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (12.570.86)
# Collecting docker<8.0.0,>=7.0.0 (from inference)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting typer<=0.12.5,>=0.9.0 (from inference)
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: PyYAML~=6.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (6.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (4.67.1)
# Requirement already satisfied: py-cpuinfo~=9.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (9.0.0)
# Collecting aiohttp<=3.10.11,>=3.9.0 (from inference)
#   Downloading aiohttp-3.10.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting rich<13.10.0,>=13.0.0 (from inference)
#   Downloading rich-13.0.1-py3-none-any.whl.metadata (18 kB)
# Collecting dataclasses-json~=0.6.0 (from inference)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (6.2.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (1.18.3)
# Collecting aioice<1.0.0,>=0.9.0 (from aiortc~=1.9.0->inference)
#   Downloading aioice-0.9.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting av<13.0.0,>=9.0.0 (from aiortc~=1.9.0->inference)
#   Downloading av-12.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference) (1.17.1)
# Requirement already satisfied: cryptography>=42.0.0 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference) (43.0.3)
# Requirement already satisfied: google-crc32c>=1.1 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference) (1.7.0)
# Collecting pyee>=9.0.0 (from aiortc~=1.9.0->inference)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pylibsrtp>=0.10.0 (from aiortc~=1.9.0->inference)
#   Downloading pylibsrtp-0.11.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: pyopenssl>=24.0.0 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference) (24.2.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from anthropic~=0.34.2->inference) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from anthropic~=0.34.2->inference) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from anthropic~=0.34.2->inference) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from anthropic~=0.34.2->inference) (1.3.1)
# Requirement already satisfied: tzlocal>=3.0 in /usr/local/lib/python3.11/dist-packages (from APScheduler<4.0.0,>=3.10.1->inference) (5.3.1)
# Collecting aiofiles (from asyncua~=1.1.5->inference)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiosqlite (from asyncua~=1.1.5->inference)
#   Downloading aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from asyncua~=1.1.5->inference) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from asyncua~=1.1.5->inference) (2025.1)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from asyncua~=1.1.5->inference) (2.4.0)
# Collecting botocore<1.36.0,>=1.35.60 (from boto3<=1.35.60->inference)
#   Downloading botocore-1.35.99-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<=1.35.60->inference)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<=1.35.60->inference)
#   Downloading s3transfer-0.10.4-py3-none-any.whl.metadata (1.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json~=0.6.0->inference)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json~=0.6.0->inference)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from docker<8.0.0,>=7.0.0->inference) (2.3.0)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi<0.111,>=0.100->inference)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.1->inference) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.1->inference) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.1->inference) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.25.1->inference) (0.14.0)
# Collecting coloredlogs (from onnxruntime<1.20.0,>=1.15.1->inference)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime<1.20.0,>=1.15.1->inference) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime<1.20.0,>=1.15.1->inference) (5.29.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime<1.20.0,>=1.15.1->inference) (1.13.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=2.0.0->inference) (2025.1)
# Requirement already satisfied: prometheus-client<1.0.0,>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from prometheus-fastapi-instrumentator<=6.0.0->inference) (0.21.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.6->inference) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.6->inference) (2.27.2)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.11/dist-packages (from pydot~=2.0.0->inference) (3.2.1)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest<9.0.0,>=8.0.0->inference) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest<9.0.0,>=8.0.0->inference) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.0->inference) (3.4.1)
# Collecting commonmark<0.10.0,>=0.9.0 (from rich<13.10.0,>=13.0.0->inference)
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from rich<13.10.0,>=13.0.0->inference) (2.18.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from scikit-image<=0.24.0,>=0.19.0->inference) (1.14.1)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image<=0.24.0,>=0.19.0->inference) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image<=0.24.0,>=0.19.0->inference) (2025.3.13)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image<=0.24.0,>=0.19.0->inference) (0.4)
# Requirement already satisfied: contourpy>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from supervision<=0.30.0,>=0.25.1->inference) (1.3.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from supervision<=0.30.0,>=0.25.1->inference) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from supervision<=0.30.0,>=0.25.1->inference) (3.10.0)
# Collecting requests-file>=1.4 (from tldextract~=5.1.2->inference)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers<0.22.0,>=0.19.0->inference) (0.29.3)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from twilio~=9.3.7->inference) (2.10.1)
# Collecting aiohttp-retry==2.8.3 (from twilio~=9.3.7->inference)
#   Downloading aiohttp_retry-2.8.3-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<=0.12.5,>=0.9.0->inference) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<=0.12.5,>=0.9.0->inference) (1.5.4)
# Collecting dnspython>=2.0.0 (from aioice<1.0.0,>=0.9.0->aiortc~=1.9.0->inference)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting ifaddr>=0.2.0 (from aioice<1.0.0,>=0.9.0->aiortc~=1.9.0->inference)
#   Downloading ifaddr-0.2.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.0->aiortc~=1.9.0->inference) (2.22)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<0.22.0,>=0.19.0->inference) (2025.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference) (1.4.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->asyncua~=1.1.5->inference) (1.17.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json~=0.6.0->inference)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<=3.10.11,>=3.9.0->inference) (0.3.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<1.20.0,>=1.15.1->inference)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime<1.20.0,>=1.15.1->inference) (1.3.0)
# Downloading inference-0.42.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 4.1 MB/s eta 0:00:00
# Downloading pylogix-1.0.5-py2.py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 4.4 MB/s eta 0:00:00
# Downloading aiohttp-3.10.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.5 MB/s eta 0:00:00
# Downloading aiortc-1.9.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 43.8 MB/s eta 0:00:00
# Downloading anthropic-0.34.2-py3-none-any.whl (891 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 891.9/891.9 kB 30.8 MB/s eta 0:00:00
# Downloading APScheduler-3.11.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 4.3 MB/s eta 0:00:00
# Downloading asyncua-1.1.5-py3-none-any.whl (774 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.7/774.7 kB 30.8 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading boto3-1.35.60-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 9.3 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 8.1 MB/s eta 0:00:00
# Downloading fastapi-0.110.3-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 5.8 MB/s eta 0:00:00
# Downloading filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.4 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 32.4 MB/s eta 0:00:00
# Downloading onnxruntime-1.19.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 17.5 MB/s eta 0:00:00
# Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 MB 8.7 MB/s eta 0:00:00
# Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 8.7 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 42.1 MB/s eta 0:00:00
# Downloading prometheus_fastapi_instrumentator-6.0.0-py3-none-any.whl (18 kB)
# Downloading pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Downloading pydot-2.0.0-py3-none-any.whl (22 kB)
# Downloading pymodbus-3.8.3-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.7/160.7 kB 9.2 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading redis-5.0.8-py3-none-any.whl (255 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.6/255.6 kB 15.3 MB/s eta 0:00:00
# Downloading rich-13.0.1-py3-none-any.whl (238 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.1/238.1 kB 12.8 MB/s eta 0:00:00
# Downloading scikit_image-0.24.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 34.4 MB/s eta 0:00:00
# Downloading slack_sdk-3.33.5-py2.py3-none-any.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.3/292.3 kB 17.9 MB/s eta 0:00:00
# Downloading structlog-24.4.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 4.3 MB/s eta 0:00:00
# Downloading supervision-0.25.1-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 10.3 MB/s eta 0:00:00
# Downloading tldextract-5.1.3-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 7.3 MB/s eta 0:00:00
# Downloading twilio-9.3.8-py2.py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 42.0 MB/s eta 0:00:00
# Downloading aiohttp_retry-2.8.3-py3-none-any.whl (9.8 kB)
# Downloading typer-0.12.5-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 3.4 MB/s eta 0:00:00
# Downloading wheel-0.45.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.4 MB/s eta 0:00:00
# Downloading zxing_cpp-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (941 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 941.4/941.4 kB 30.0 MB/s eta 0:00:00
# Downloading aioice-0.9.0-py3-none-any.whl (24 kB)
# Downloading av-12.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 11.5 MB/s eta 0:00:00
# Downloading botocore-1.35.99-py3-none-any.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 56.5 MB/s eta 0:00:00
# Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 3.5 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.6 MB/s eta 0:00:00
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Downloading pylibsrtp-0.11.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 53.0 MB/s eta 0:00:00
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Downloading s3transfer-0.10.4-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 5.2 MB/s eta 0:00:00
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 5.0 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 20.5 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.7 MB/s eta 0:00:00
# Downloading ifaddr-0.2.0-py3-none-any.whl (12 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Building wheels for collected packages: paho-mqtt, pybase64
#   Building wheel for paho-mqtt (setup.py) ... done
#   Created wheel for paho-mqtt: filename=paho_mqtt-1.6.1-py3-none-any.whl size=62117 sha256=a61207df134226468bcf025fc9875a9a2d1b60faca7c7b3e3c39bb97aeee8303
#   Stored in directory: /root/.cache/pip/wheels/29/ea/a5/ba9a63aaf4cd4e16e8a87ee31fb4d11b04ff5e1735d312619a
#   Building wheel for pybase64 (pyproject.toml) ... done
#   Created wheel for pybase64: filename=pybase64-1.0.2-cp311-cp311-linux_x86_64.whl size=146808 sha256=b7b343165398855b48a974891f1a9d4eeb1feea677f0a92a73b74253ef2edfc8
#   Stored in directory: /root/.cache/pip/wheels/3d/c0/15/5e79fe7fd3f97ebaf4c080e7c337fb06c1d01bc61905dcb26b
# Successfully built paho-mqtt pybase64
# Installing collected packages: pylogix, paho-mqtt, ifaddr, commonmark, zxing-cpp, wheel, structlog, slack-sdk, rich, redis, python-dotenv, pymodbus, pyee, pydot, pybase64, pillow, numpy, mypy-extensions, marshmallow, jmespath, humanfriendly, filelock, dnspython, backoff, av, APScheduler, aiosqlite, aiofiles, typing-inspect, typer, starlette, requests-file, pylibsrtp, opencv-python, opencv-contrib-python, httpx, docker, coloredlogs, botocore, aioice, aiohttp, tldextract, scikit-image, s3transfer, pydantic-settings, onnxruntime, fastapi, dataclasses-json, aiohttp-retry, twilio, supervision, prometheus-fastapi-instrumentator, boto3, asyncua, anthropic, aiortc, inference
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.45.1
#     Uninstalling wheel-0.45.1:
#       Successfully uninstalled wheel-0.45.1
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
#   Attempting uninstall: pydot
#     Found existing installation: pydot 3.0.4
#     Uninstalling pydot-3.0.4:
#       Successfully uninstalled pydot-3.0.4
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.18.0
#     Uninstalling filelock-3.18.0:
#       Successfully uninstalled filelock-3.18.0
#   Attempting uninstall: typer
#     Found existing installation: typer 0.15.2
#     Uninstalling typer-0.15.2:
#       Successfully uninstalled typer-0.15.2
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.11.0.86
#     Uninstalling opencv-python-4.11.0.86:
#       Successfully uninstalled opencv-python-4.11.0.86
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.11.0.86
#     Uninstalling opencv-contrib-python-4.11.0.86:
#       Successfully uninstalled opencv-contrib-python-4.11.0.86
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.14
#     Uninstalling aiohttp-3.11.14:
#       Successfully uninstalled aiohttp-3.11.14
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.25.2
#     Uninstalling scikit-image-0.25.2:
#       Successfully uninstalled scikit-image-0.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# google-genai 1.5.0 requires httpx<1.0.0dev,>=0.28.1, but you have httpx 0.27.2 which is incompatible.
# pymc 5.21.1 requires rich>=13.7.1, but you have rich 13.0.1 which is incompatible.
# Successfully installed APScheduler-3.11.0 aiofiles-24.1.0 aiohttp-3.10.11 aiohttp-retry-2.8.3 aioice-0.9.0 aiortc-1.9.0 aiosqlite-0.21.0 anthropic-0.34.2 asyncua-1.1.5 av-12.3.0 backoff-2.2.1 boto3-1.35.60 botocore-1.35.99 coloredlogs-15.0.1 commonmark-0.9.1 dataclasses-json-0.6.7 dnspython-2.7.0 docker-7.1.0 fastapi-0.110.3 filelock-3.17.0 httpx-0.27.2 humanfriendly-10.0 ifaddr-0.2.0 inference-0.42.1 jmespath-1.0.1 marshmallow-3.26.1 mypy-extensions-1.0.0 numpy-1.26.4 onnxruntime-1.19.2 opencv-contrib-python-4.10.0.84 opencv-python-4.10.0.84 paho-mqtt-1.6.1 pillow-10.4.0 prometheus-fastapi-instrumentator-6.0.0 pybase64-1.0.2 pydantic-settings-2.8.1 pydot-2.0.0 pyee-13.0.0 pylibsrtp-0.11.0 pylogix-1.0.5 pymodbus-3.8.3 python-dotenv-1.0.1 redis-5.0.8 requests-file-2.1.0 rich-13.0.1 s3transfer-0.10.4 scikit-image-0.24.0 slack-sdk-3.33.5 starlette-0.37.2 structlog-24.4.0 supervision-0.25.1 tldextract-5.1.3 twilio-9.3.8 typer-0.12.5 typing-inspect-0.9.0 wheel-0.45.0 zxing-cpp-2.2.0

# %%
# !pip install -q git+https://github.com/roboflow/sports.git
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for sports (setup.py) ... done

# %%
# !pip uninstall -y supervision && pip install -q supervision>=0.23.0
# Out:
# Found existing installation: supervision 0.25.1
# Uninstalling supervision-0.25.1:
#   Successfully uninstalled supervision-0.25.1

# %% [markdown]
# # Loading Player Detection Model from Yolo

# %%
from inference import get_model
from google.colab import userdata

ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')
PLAYER_DETECTION_MODEL_ID = "football-players-detection-3zvbc/12"
PLAYER_DETECTION_MODEL = get_model(model_id=PLAYER_DETECTION_MODEL_ID, api_key=ROBOFLOW_API_KEY)
# Out:
# ModelDependencyMissing: Your `inference` configuration does not support Qwen2.5-VL model. Use pip install 'inference[transformers]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support SAM model. Use pip install 'inference[sam]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support SAM model. Use pip install 'inference[sam]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support SAM model. Use pip install 'inference[clip]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support Gaze Detection model. Use pip install 'inference[gaze]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support GroundingDINO model. Use pip install 'inference[grounding-dino]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support YoloWorld model. Use pip install 'inference[yolo-world]' to install missing requirements.
# UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
# UserWarning: Specified provider 'OpenVINOExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
# UserWarning: Specified provider 'CoreMLExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'

# %% [markdown]
# # Team Classifying

# %%
from tqdm import tqdm
import supervision as sv
SOURCE_VIDEO_PATH = "/content/test_pl.mp4"
PLAYER_ID = 2
STRIDE = 30

frame_generator = sv.get_video_frames_generator(
    source_path=SOURCE_VIDEO_PATH, stride=STRIDE)

crops = []
for frame in tqdm(frame_generator, desc='collecting crops'):
    result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
    detections = sv.Detections.from_inference(result)
    detections = detections.with_nms(threshold=0.5, class_agnostic=True)
    detections = detections[detections.class_id == PLAYER_ID]
    players_crops = [sv.crop_image(frame, xyxy) for xyxy in detections.xyxy]
    crops += players_crops
# Out:
# collecting crops: 26it [08:19, 19.19s/it]

# %%
import torch
from transformers import AutoProcessor, SiglipVisionModel

SIGLIP_MODEL_PATH = 'google/siglip-base-patch16-224'

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
EMBEDDINGS_MODEL = SiglipVisionModel.from_pretrained(SIGLIP_MODEL_PATH).to(DEVICE)
EMBEDDINGS_PROCESSOR = AutoProcessor.from_pretrained(SIGLIP_MODEL_PATH)
# Out:
# UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/813M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/368 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/711 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/798k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/409 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.40M [00:00<?, ?B/s]

# %%
import numpy as np
from more_itertools import chunked

BATCH_SIZE = 32

crops = [sv.cv2_to_pillow(crop) for crop in crops]
batches = chunked(crops, BATCH_SIZE)
data = []
with torch.no_grad():
    for batch in tqdm(batches, desc='embedding extraction'):
        inputs = EMBEDDINGS_PROCESSOR(images=batch, return_tensors="pt").to(DEVICE)
        outputs = EMBEDDINGS_MODEL(**inputs)
        embeddings = torch.mean(outputs.last_hidden_state, dim=1).cpu().numpy()
        data.append(embeddings)

data = np.concatenate(data)
# Out:
# embedding extraction: 17it [06:32, 23.09s/it]

# %%
import umap
from sklearn.cluster import KMeans

REDUCER = umap.UMAP(n_components=3)
CLUSTERING_MODEL = KMeans(n_clusters=2)

# %%
import supervision as sv
from tqdm import tqdm
from sports.common.team import TeamClassifier

SOURCE_VIDEO_PATH = "/content/test_pl.mp4"
PLAYER_ID = 2
STRIDE = 30

frame_generator = sv.get_video_frames_generator(
    source_path=SOURCE_VIDEO_PATH, stride=STRIDE)

crops = []
for frame in tqdm(frame_generator, desc='collecting crops'):
    result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
    detections = sv.Detections.from_inference(result)
    players_detections = detections[detections.class_id == PLAYER_ID]
    players_crops = [sv.crop_image(frame, xyxy) for xyxy in detections.xyxy]
    crops += players_crops

team_classifier = TeamClassifier(device="cpu")
team_classifier.fit(crops)
# Out:
# collecting crops: 26it [08:17, 19.12s/it]
# Embedding extraction: 21it [08:18, 23.74s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.

# %% [markdown]
# # Goalkeeper Detection

# %%
import numpy as np
import supervision as sv

def resolve_goalkeepers_team_id(
    players: sv.Detections,
    goalkeepers: sv.Detections
) -> np.ndarray:
    goalkeepers_xy = goalkeepers.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
    players_xy = players.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
    team_0_centroid = players_xy[players.class_id == 0].mean(axis=0)
    team_1_centroid = players_xy[players.class_id == 1].mean(axis=0)
    goalkeepers_team_id = []
    for goalkeeper_xy in goalkeepers_xy:
        dist_0 = np.linalg.norm(goalkeeper_xy - team_0_centroid)
        dist_1 = np.linalg.norm(goalkeeper_xy - team_1_centroid)
        goalkeepers_team_id.append(0 if dist_0 < dist_1 else 1)

    return np.array(goalkeepers_team_id)

# %% [markdown]
# # Load Key points Detection for Pitch from Yolo

# %%
from inference import get_model
from google.colab import userdata

ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')
FIELD_DETECTION_MODEL_ID = "football-field-detection-f07vi/15"
FIELD_DETECTION_MODEL = get_model(model_id=FIELD_DETECTION_MODEL_ID, api_key=ROBOFLOW_API_KEY)
# Out:
# UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
# UserWarning: Specified provider 'OpenVINOExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
# UserWarning: Specified provider 'CoreMLExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'

# %%
from sports.annotators.soccer import draw_pitch
from sports.configs.soccer import SoccerPitchConfiguration

CONFIG = SoccerPitchConfiguration()

annotated_frame = draw_pitch(CONFIG)

# %%
import supervision as sv
from tqdm import tqdm
from sports.common.team import TeamClassifier

SOURCE_VIDEO_PATH = "/content/test_pl.mp4"
PLAYER_ID = 2
STRIDE = 30

frame_generator = sv.get_video_frames_generator(
    source_path=SOURCE_VIDEO_PATH, stride=STRIDE)

crops = []
for frame in tqdm(frame_generator, desc='collecting crops'):
    result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
    detections = sv.Detections.from_inference(result)
    players_detections = detections[detections.class_id == PLAYER_ID]
    players_crops = [sv.crop_image(frame, xyxy) for xyxy in detections.xyxy]
    crops += players_crops

team_classifier = TeamClassifier(device="cpu")
team_classifier.fit(crops)
# Out:
# collecting crops: 26it [08:21, 19.28s/it]
# Embedding extraction: 21it [08:15, 23.58s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.

# %% [markdown]
# # Check the Frame

# %%
import supervision as sv
import cv2
import numpy as np
from sports.common.view import ViewTransformer
from sports.annotators.soccer import (
    draw_pitch,
    draw_points_on_pitch
)



# Set up video path and IDs
SOURCE_VIDEO_PATH = "/content/test_pl.mp4"
BALL_ID, GOALKEEPER_ID, PLAYER_ID, REFEREE_ID = 0, 1, 2, 3

# Annotators for drawing detections
ellipse_annotator = sv.EllipseAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF','#C8102E','#FFD700']),
    thickness=2
)
label_annotator = sv.LabelAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF','#C8102E','#FFD700']),
    text_color=sv.Color.from_hex('#000000'),
    text_position=sv.Position.BOTTOM_CENTER
)
triangle_annotator = sv.TriangleAnnotator(
    color=sv.Color.from_hex('#FFD700'),
    base=20, height=17
)

# Object Tracker
tracker = sv.ByteTrack()
tracker.reset()

# Read frame
frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)
frame = next(frame_generator)

# Object Detection
result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
detections = sv.Detections.from_inference(result)

# Filter detections
ball_detections = detections[detections.class_id == BALL_ID]
ball_detections.xyxy = sv.pad_boxes(xyxy=ball_detections.xyxy, px=10)

all_detections = detections[detections.class_id != BALL_ID].with_nms(threshold=0.5, class_agnostic=True)
all_detections = tracker.update_with_detections(detections=all_detections)

players_detections = all_detections[all_detections.class_id == PLAYER_ID]
goalkeepers_detections = all_detections[all_detections.class_id == GOALKEEPER_ID]
referees_detections = all_detections[all_detections.class_id == REFEREE_ID]

# Assign team classifications
players_crops = [sv.crop_image(frame, xyxy) for xyxy in players_detections.xyxy]
players_detections.class_id = team_classifier.predict(players_crops)

goalkeepers_detections.class_id = resolve_goalkeepers_team_id(players_detections, goalkeepers_detections)
referees_detections.class_id -= 1  # Adjust referee class ID

all_detections = sv.Detections.merge([players_detections, goalkeepers_detections, referees_detections])

# Ensure class_id is of integer type before annotation
all_detections.class_id = all_detections.class_id.astype(int)

# Annotate frame
labels = [f"#{tracker_id}" for tracker_id in all_detections.tracker_id]
annotated_frame = frame.copy()
annotated_frame = ellipse_annotator.annotate(annotated_frame, all_detections)
annotated_frame = label_annotator.annotate(annotated_frame, all_detections, labels=labels)
annotated_frame = triangle_annotator.annotate(annotated_frame, ball_detections)

# Field Key Points Detection
result = FIELD_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
key_points = sv.KeyPoints.from_inference(result)

# Perspective Transformation
filter = key_points.confidence[0] > 0.5
frame_reference_points = key_points.xy[0][filter]
pitch_reference_points = np.array(CONFIG.vertices)[filter]

transformer = ViewTransformer(source=frame_reference_points, target=pitch_reference_points)

frame_ball_xy = ball_detections.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
pitch_ball_xy = transformer.transform_points(points=frame_ball_xy)

players_xy = players_detections.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
pitch_players_xy = transformer.transform_points(points=players_xy)

referees_xy = referees_detections.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
pitch_referees_xy = transformer.transform_points(points=referees_xy)

# Draw Radar View
radar_frame = draw_pitch(CONFIG)
radar_frame = draw_points_on_pitch(CONFIG, pitch_ball_xy, face_color=sv.Color.WHITE, edge_color=sv.Color.BLACK, radius=10, pitch=radar_frame)
radar_frame = draw_points_on_pitch(CONFIG, pitch_players_xy[players_detections.class_id == 0], face_color=sv.Color.from_hex('#00BFFF'), edge_color=sv.Color.BLACK, radius=16, pitch=radar_frame)
radar_frame = draw_points_on_pitch(CONFIG, pitch_players_xy[players_detections.class_id == 1], face_color=sv.Color.from_hex('#C8102E'), edge_color=sv.Color.BLACK, radius=16, pitch=radar_frame)
radar_frame = draw_points_on_pitch(CONFIG, pitch_referees_xy, face_color=sv.Color.from_hex('FFD700'), edge_color=sv.Color.BLACK, radius=16, pitch=radar_frame)

# Resize radar
radar_resized = cv2.resize(radar_frame, (800, 500))

# Place radar in bottom-right corner
h, w, _ = annotated_frame.shape
x_offset = w - 810
y_offset = h - 510

# Convert radar to BGR if needed
if radar_resized.shape[2] == 4:
    radar_resized = cv2.cvtColor(radar_resized, cv2.COLOR_RGBA2RGB)

# Blend radar with opacity
alpha = 0.6
overlay = annotated_frame.copy()
overlay[y_offset:y_offset + 500, x_offset:x_offset + 800] = radar_resized
cv2.addWeighted(overlay, alpha, annotated_frame, 1 - alpha, 0, annotated_frame)

# Show final frame
sv.plot_image(annotated_frame)
# Out:
# Embedding extraction: 1it [00:24, 24.01s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.

# %% [markdown]
# # Final Video Output

# %%
from tqdm import tqdm
import supervision as sv
import cv2
import numpy as np
from sports.common.view import ViewTransformer
from sports.annotators.soccer import (
    draw_pitch,
    draw_points_on_pitch
)

# Set up video path and IDs
SOURCE_VIDEO_PATH = "/content/test_pl.mp4"
TARGET_VIDEO_PATH = "/content/result.mp4"

BALL_ID, GOALKEEPER_ID, PLAYER_ID, REFEREE_ID = 0, 1, 2, 3

# Annotators for drawing detections
ellipse_annotator = sv.EllipseAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF','#C8102E','#FFD700']),
    thickness=2
)
label_annotator = sv.LabelAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF','#C8102E','#FFD700']),
    text_color=sv.Color.from_hex('#000000'),
    text_position=sv.Position.BOTTOM_CENTER
)
triangle_annotator = sv.TriangleAnnotator(
    color=sv.Color.from_hex('#FFD700'),
    base=20, height=17
)

# Object Tracker
tracker = sv.ByteTrack()
tracker.reset()

# Read frame
video_info = sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
video_sink = sv.VideoSink(TARGET_VIDEO_PATH, video_info=video_info)
frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)

with video_sink:
    for frame in tqdm(frame_generator, total=video_info.total_frames):
        # Object Detection
        result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
        detections = sv.Detections.from_inference(result)

        # Filter detections
        ball_detections = detections[detections.class_id == BALL_ID]
        ball_detections.xyxy = sv.pad_boxes(xyxy=ball_detections.xyxy, px=10)

        all_detections = detections[detections.class_id != BALL_ID].with_nms(threshold=0.5, class_agnostic=True)
        all_detections = tracker.update_with_detections(detections=all_detections)

        # Ensure `tracker_id` and `class_id` are valid
        if all_detections.tracker_id is not None:
            valid_indices = ~np.isnan(all_detections.tracker_id)  # Remove NaN tracker IDs
            all_detections = all_detections[valid_indices]
            all_detections.tracker_id = all_detections.tracker_id.astype(int)

        players_detections = all_detections[all_detections.class_id == PLAYER_ID]
        goalkeepers_detections = all_detections[all_detections.class_id == GOALKEEPER_ID]
        referees_detections = all_detections[all_detections.class_id == REFEREE_ID]

        # Assign team classifications
        players_crops = [sv.crop_image(frame, xyxy) for xyxy in players_detections.xyxy]
        players_detections.class_id = team_classifier.predict(players_crops)

        goalkeepers_detections.class_id = resolve_goalkeepers_team_id(players_detections, goalkeepers_detections)
        referees_detections.class_id -= 1  # Adjust referee class ID

        # Ensure `class_id` is integer
        all_detections = sv.Detections.merge([players_detections, goalkeepers_detections, referees_detections])
        all_detections.class_id = all_detections.class_id.astype(int)

        # Annotate frame
        labels = [f"#{int(tracker_id)}" for tracker_id in all_detections.tracker_id]  # Convert IDs to int
        annotated_frame = frame.copy()
        annotated_frame = ellipse_annotator.annotate(annotated_frame, all_detections)
        annotated_frame = label_annotator.annotate(annotated_frame, all_detections, labels=labels)
        annotated_frame = triangle_annotator.annotate(annotated_frame, ball_detections)

        # Field Key Points Detection
        result = FIELD_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
        key_points = sv.KeyPoints.from_inference(result)

        # Perspective Transformation
        filter = key_points.confidence[0] > 0.5
        frame_reference_points = key_points.xy[0][filter]
        pitch_reference_points = np.array(CONFIG.vertices)[filter]

        transformer = ViewTransformer(source=frame_reference_points, target=pitch_reference_points)

        frame_ball_xy = ball_detections.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
        pitch_ball_xy = transformer.transform_points(points=frame_ball_xy)

        players_xy = players_detections.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
        pitch_players_xy = transformer.transform_points(points=players_xy)

        referees_xy = referees_detections.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
        pitch_referees_xy = transformer.transform_points(points=referees_xy)

        # Draw Radar View
        radar_frame = draw_pitch(CONFIG)
        radar_frame = draw_points_on_pitch(CONFIG, pitch_ball_xy, face_color=sv.Color.WHITE, edge_color=sv.Color.BLACK, radius=10, pitch=radar_frame)
        radar_frame = draw_points_on_pitch(CONFIG, pitch_players_xy[players_detections.class_id == 0], face_color=sv.Color.from_hex('#00BFFF'), edge_color=sv.Color.BLACK, radius=16, pitch=radar_frame)
        radar_frame = draw_points_on_pitch(CONFIG, pitch_players_xy[players_detections.class_id == 1], face_color=sv.Color.from_hex('#C8102E'), edge_color=sv.Color.BLACK, radius=16, pitch=radar_frame)
        radar_frame = draw_points_on_pitch(CONFIG, pitch_referees_xy, face_color=sv.Color.from_hex('FFD700'), edge_color=sv.Color.BLACK, radius=16, pitch=radar_frame)

        # Resize radar
        radar_resized = cv2.resize(radar_frame, (800, 500))

        # Place radar in bottom-right corner
        h, w, _ = annotated_frame.shape
        x_offset = w - 810
        y_offset = h - 510

        # Convert radar to BGR if needed
        if radar_resized.shape[2] == 4:
            radar_resized = cv2.cvtColor(radar_resized, cv2.COLOR_RGBA2RGB)

        # Blend radar with opacity
        alpha = 0.6
        overlay = annotated_frame.copy()
        overlay[y_offset:y_offset + 500, x_offset:x_offset + 800] = radar_resized
        cv2.addWeighted(overlay, alpha, annotated_frame, 1 - alpha, 0, annotated_frame)

        # Write frame to video
        video_sink.write_frame(annotated_frame)
# Out:
#   0%|          | 0/769 [00:00<?, ?it/s]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:14, 14.38s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   0%|          | 1/769 [00:38<8:08:47, 38.19s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:14, 14.37s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   0%|          | 2/769 [01:16<8:11:36, 38.46s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:14, 14.25s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   0%|          | 3/769 [01:54<8:06:37, 38.12s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:14, 14.18s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   1%|          | 4/769 [02:32<8:03:55, 37.96s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:13, 13.75s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   1%|          | 5/769 [03:09<8:00:52, 37.76s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:13, 13.60s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   1%|          | 6/769 [03:46<7:55:15, 37.37s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:13, 13.66s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   1%|          | 7/769 [04:23<7:53:00, 37.25s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:13, 13.62s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   1%|          | 8/769 [05:00<7:52:00, 37.21s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:13, 13.67s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   1%|          | 9/769 [05:37<7:50:42, 37.16s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:13, 13.89s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   1%|▏         | 10/769 [06:14<7:48:39, 37.05s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:13, 13.58s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   1%|▏         | 11/769 [06:51<7:48:58, 37.12s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:13, 13.69s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   2%|▏         | 12/769 [07:28<7:48:21, 37.12s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:13, 13.72s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   2%|▏         | 13/769 [08:05<7:46:10, 37.00s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:13, 13.77s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   2%|▏         | 14/769 [08:42<7:44:32, 36.92s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:18, 18.76s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   2%|▏         | 15/769 [09:26<8:11:00, 39.07s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:13, 13.82s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   2%|▏         | 16/769 [10:03<8:04:48, 38.63s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:13, 13.76s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   2%|▏         | 17/769 [10:40<7:57:54, 38.13s/it]
# Embedding extraction: 0it [00:00, ?it/s]
# Embedding extraction: 1it [00:15, 15.16s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   2%|▏         |